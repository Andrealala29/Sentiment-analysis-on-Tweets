# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover
from pyspark.ml.feature import Word2Vec, CountVectorizer, HashingTF, IDF
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator
import numpy as np

# %% [markdown]
# # 1. Read Data

# %%
# Read Data to pyspark dataframe
# Since we want to further investigate precision and recall of negative reviews,
# we change the label 0 to 1 and label 4 to 0
PATH = 'gs://bucket-ljy/data.csv'
data = spark.read.format('com.databricks.spark.csv').options(header='false', inferschema='true').load(PATH)
data = data.selectExpr("_c0 as label", "_c1 as id", "_c2 as date", "_c3 as flag", "_c4 as user", "_c5 as text")\
            .select(['text', 'label']).replace(0, 1).replace(4, 0)

# %%
data.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- label: integer (nullable = true)

# %%
data.show(5)
# Out:
# +--------------------+-----+
# |                text|label|
# +--------------------+-----+
# |@switchfoot http:...|    1|
# |is upset that he ...|    1|
# |@Kenichan I dived...|    1|
# |my whole body fee...|    1|
# |@nationwideclass ...|    1|
# +--------------------+-----+
# only showing top 5 rows

# %%
train_data, test_data = data.randomSplit([0.7, 0.3], seed = 100)
train_data.cache()
test_data.cache()
# Out:
# DataFrame[text: string, label: int]

# %%
train_data.groupBy('label').count().show()
# Out:
# +-----+------+
# |label| count|
# +-----+------+
# |    1|559308|
# |    0|559842|
# +-----+------+

# %%
test_data.groupBy('label').count().show()
# Out:
# +-----+------+
# |label| count|
# +-----+------+
# |    1|240692|
# |    0|240158|
# +-----+------+

# %%
train_data.show()
# Out:
# [Stage 153:>                                                        (0 + 1) / 1]
# +--------------------+-----+
# |                text|label|
# +--------------------+-----+
# |                 ...|    1|
# |                 ...|    1|
# |                 ...|    1|
# |               I ...|    1|
# |               ju...|    1|
# |             i ju...|    1|
# |            Miss ...|    1|
# |          .. Omga...|    1|
# |           FUCK YOU!|    1|
# |         or i jus...|    1|
# |        my head f...|    1|
# |       FS keeps c...|    1|
# |       Orlando Lo...|    1|
# |       Sunny Agai...|    1|
# |      My current ...|    1|
# |      i think i'm...|    1|
# |      rinitis suc...|    1|
# |      this weeken...|    1|
# |            #canucks|    1|
# |     &gt;( &gt;( ...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # 2. Feature Engineering

# %%
# preprocess data
tokenizer = Tokenizer(inputCol="text", outputCol="words")
remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")

# three different feature engineering methods

# word2vec
word2Vec = Word2Vec(vectorSize=100, minCount=2, inputCol="filtered_words", outputCol="features")
# count vectorizer
count_vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="features")
# TF-IDF
hashing_tf = HashingTF(inputCol="filtered_words", outputCol="raw_features", numFeatures=10000)
idf = IDF(inputCol="raw_features", outputCol="features")

# %% [markdown]
# # 3. Models

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.classification import LinearSVC
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.classification import GBTClassifier

# %%
# Six different models for binary classification
nb = NaiveBayes(smoothing=1.0, modelType="multinomial")
lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10)
svm = LinearSVC(featuresCol="features", labelCol="label", maxIter=10)
dt = DecisionTreeClassifier(featuresCol="features", labelCol="label")
rf = RandomForestClassifier(featuresCol="features", labelCol="label", numTrees=50, maxDepth=6,minInstancesPerNode=2)
# gbm = GBTClassifier(featuresCol="features", labelCol="label", maxIter=10)

# %% [markdown]
# # 4. Training and Evaluation

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# %%
def train(train_data, pipelineFit, model):
    
    # feature engineering
    processed_data = pipelineFit.transform(train_data)
    
    # Fit the model with processed text
    model = model.fit(processed_data)
    
    return model

# %%
def evaluate(test_data, pipeline_feat, model):
    
    # feature engineering
    processed_data = pipeline_feat.transform(test_data)
    # make prediction
    predictions = model.transform(processed_data)
    
    # evaluators
    evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")
    evaluator_auc = BinaryClassificationEvaluator()
    
    # accuracy
    evaluator.setMetricName('accuracy')
    accuracy = evaluator.evaluate(predictions)
    # precision
    evaluator.setMetricName('precisionByLabel')
    precision = evaluator.evaluate(predictions)
    # recall
    evaluator.setMetricName('recallByLabel')
    recall = evaluator.evaluate(predictions)
    # auc
    auc = evaluator_auc.evaluate(predictions)
    
    return [accuracy, precision, recall, auc]

# %%
def crossvalidation(train_data, test_data, model, paramGrid, evaluator, pipelineFit):
    processed_train = pipelineFit.transform(train_data)
    processed_test = pipelineFit.transform(test_data)
    #evaluator = MulticlassClassificationEvaluator(predictionCol="prediction", metricName="accuracy")
    
    cv = CrossValidator(estimator=model,
                          estimatorParamMaps=paramGrid,
                          evaluator=evaluator,
                          numFolds=5)
    cvModel = cv.fit(processed_train)
    
    predictions = cvModel.transform(processed_test)
    
    # average metric(use accuracy)
    print(cvModel.avgMetrics)
    # parameter map
    print(cvModel.getEstimatorParamMaps())
    # parameter with highest average metric
    print(cvModel.getEstimatorParamMaps()[np.argmax(cvModel.avgMetrics)])
    
    
    evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")
    evaluator_auc = BinaryClassificationEvaluator()
    
    # accuracy
    
    evaluator.setMetricName('accuracy')
    accuracy = evaluator.evaluate(predictions)
    # precision
    evaluator.setMetricName('precisionByLabel')
    precision = evaluator.evaluate(predictions)
    # recall
    evaluator.setMetricName('recallByLabel')
    recall = evaluator.evaluate(predictions)
    # auc
    auc = evaluator_auc.evaluate(predictions)
    
    return [accuracy, precision, recall, auc]

# %%
cv_evaluator = MulticlassClassificationEvaluator(predictionCol="prediction", metricName="accuracy")

# %%
nb_model = NaiveBayes(modelType="multinomial")
svm_model = LinearSVC(featuresCol="features", labelCol="label")
lr_model = LogisticRegression(featuresCol="features", labelCol="label")
dt_model = DecisionTreeClassifier(featuresCol="features", labelCol="label")

# %%
nb_grid = ParamGridBuilder() \
    .addGrid(nb_model.smoothing, [0.0, 0.5, 1.0, 2.0, 3.0, 5.0]) \
    .build()
svm_grid = ParamGridBuilder() \
    .addGrid(svm_model.maxIter, [5,10,20])\
    .addGrid(svm_model.regParam, [0.0, 0.1, 0.2])\
    .build()
# .addGrid(svm_model.regParam, [0.1, 0.3, 0.5])\

lr_grid = (ParamGridBuilder()
#          .addGrid(lr_model.regParam, [0.0, 0.1, 0.2]) # regularization parameter
           .addGrid(lr_model.elasticNetParam, [0.0, 0.1, 0.5])
           .addGrid(lr.maxIter, [10, 20, 50])
           .build())
#             .addGrid(lr_model.elasticNetParam, [0.0, 0.1, 0.2]) # Elastic Net Parameter (Ridge = 0)
#             .addGrid(lr.maxIter, [10, 20, 50]) #Number of iterations
#            .addGrid(idf.numFeatures, [10, 100, 1000]) # Number of features

# %%
metrics = ['accuracy', 'precision', 'recall', 'auc']

# %% [markdown]
# ## 4.1 Count Vectorizer

# %%
feature_cv = [count_vectorizer]
# define pipeline that does feature engineering
pipeline_feat = Pipeline(stages=[tokenizer, remover]+feature_cv)
    
# Fit the pipeline to training text
pipeline_cv = pipeline_feat.fit(train_data)

# %% [markdown]
# ### 4.1.1 Naive Bayes

# %%
model_nb = train(train_data, pipeline_cv, nb)
res = evaluate(test_data, pipeline_cv, model_nb)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/16 21:50:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:51:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:51:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:51:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:51:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:51:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# [Stage 25:>                                                         (0 + 2) / 2]
# accuracy 0.7706577993349502
# precision 0.7828976864648399
# recall 0.7492283147059681
# auc 0.5030065611725745

# %%
# cross validation
res = crossvalidation(train_data, test_data, nb_model, nb_grid, cv_evaluator, pipeline_cv)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/16 21:52:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:52:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:52:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:52:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:52:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:52:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:52:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:52:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:53:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:53:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:53:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:53:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:53:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:53:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:53:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:54:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:54:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:54:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:54:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:54:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:54:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:54:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:55:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:55:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:55:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:55:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:55:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:55:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:55:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/16 21:56:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# [0.7243932314077098, 0.7648518420823351, 0.7687884132408596, 0.770805248242312, 0.7710811446992919, 0.7704748621389808]
# [{Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 0.0}, {Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 0.5}, {Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 1.0}, {Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 2.0}, {Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 3.0}, {Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 5.0}]
# {Param(parent='NaiveBayes_dec1da326641', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 3.0}
# 23/04/16 21:56:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# 23/04/16 21:56:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.0 MiB
# accuracy 0.772341258927753
# precision 0.7883819074203918
# recall 0.7447294206840819
# auc 0.5016353180349614

# %% [markdown]
# ### 4.1.2 SVM

# %%
model_svm = train(train_data, pipeline_cv, svm)
res = evaluate(test_data, pipeline_cv, model_svm)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/17 10:11:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:11:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:12:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:12:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:12:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# accuracy 0.7673846371811219
# precision 0.7675896675029799
# recall 0.7672155595082876
# auc 0.8386128521695796

# %%
# cross validation
res = crossvalidation(train_data, test_data, svm_model, svm_grid, cv_evaluator, pipeline_cv)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/17 10:12:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:12:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:12:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:12:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:13:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:13:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:13:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:13:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:13:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:14:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:14:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:14:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:14:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:15:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:15:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:15:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:15:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:15:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:15:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:16:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:16:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# ...
# 23/04/17 10:23:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:23:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:24:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:24:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:24:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:25:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:25:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:25:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 10:25:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# [0.7568825524333986, 0.7552343956032055, 0.7547227189969574, 0.7582795097839823, 0.7561861119401861, 0.7561119924053147, 0.7585768213130752, 0.7578092564961432, 0.7570430958556912]
# [{Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.1}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.2}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.1}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.2}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.1}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.2}]
# {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}
# 23/04/17 10:25:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:25:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:25:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 10:25:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# accuracy 0.7668325124384329
# precision 0.7674286596741948
# recall 0.7659325415835274
# auc 0.8377534582636721

# %% [markdown]
# ### 4.1.3 Logistic Regression

# %%
model_lr = train(train_data, pipeline_cv, lr)
res = evaluate(test_data, pipeline_cv, model_lr)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/17 12:19:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:19:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:19:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:19:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:19:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# accuracy 0.749368702652699
# precision 0.7467763404613058
# recall 0.7548644291611646
# auc 0.8089913684604183

# %%
# cross validation
res = crossvalidation(train_data, test_data, lr_model, lr_grid, cv_evaluator, pipeline_cv)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/17 11:29:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:29:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 11:30:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:30:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 11:31:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:31:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 11:32:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 11:32:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 11:32:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# ...
# 23/04/17 12:08:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:08:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:08:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/17 12:09:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# [0.7185075099456844, 0.7185075099456844, 0.7185075099456844, 0.7185075099456844, 0.7185075099456844, 0.7185075099456844, 0.7185075099456844, 0.7185075099456844, 0.7185075099456844]
# [{Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 20}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 50}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 20}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 50}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 20}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 50}]
# {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}
# 23/04/17 12:09:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:09:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:09:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 23/04/17 12:09:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# accuracy 0.7410826645331733
# precision 0.7384195960860541
# recall 0.7469247143410578
# auc 0.7780068951615077

# %% [markdown]
# ### 4.1.4 Decision Tree

# %%
model_dt = train(train_data, pipeline_cv, dt)
res = evaluate(test_data, pipeline_cv, model_dt)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/25 16:04:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 16:04:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 16:04:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 23/04/25 16:06:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1034.3 KiB
# 23/04/25 16:06:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 16:12:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 16:36:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 17:00:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 17:15:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 17:35:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 17:55:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 18:15:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.5 MiB
# 23/04/25 18:34:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 18:35:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 18:35:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 18:35:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# accuracy 0.5484411666107945
# precision 0.7544827586206897
# recall 0.14351932831904846
# auc 0.5244815822254475

# %% [markdown]
# ### 4.1.5 Random Forest

# %%
model_rf = train(train_data, pipeline_cv, rf)
res = evaluate(test_data, pipeline_cv, model_rf)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# 23/04/25 18:35:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 18:35:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/04/25 18:35:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 23/04/25 18:37:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1034.3 KiB
# 23/04/25 18:37:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.6 MiB
# 23/04/25 19:29:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.7 MiB
# 23/04/25 19:44:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.8 MiB
# 23/04/25 20:00:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.9 MiB
# 23/04/25 20:15:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.1 MiB
# 23/04/25 20:31:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 7.2 MiB
# [Stage 167:>                                                        (0 + 2) / 2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 model_rf = train(train_data, pipeline_cv, rf)
#       2 res = evaluate(test_data, pipeline_cv, model_rf)
#       3 for metric, score in zip(metrics, res):
#
# Cell In[8], line 7, in train(train_data, pipelineFit, model)
#       4 processed_data = pipelineFit.transform(train_data)
#       6 # Fit the model with processed text
# ----> 7 model = model.fit(processed_data)
#       9 return model
#
# File /usr/lib/spark/python/pyspark/ml/base.py:161, in Estimator.fit(self, dataset, params)
#     159         return self.copy(params)._fit(dataset)
#     160     else:
# --> 161         return self._fit(dataset)
#     162 else:
#     163     raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#     164                      "but got %s." % type(params))
#
# File /usr/lib/spark/python/pyspark/ml/wrapper.py:335, in JavaEstimator._fit(self, dataset)
#     334 def _fit(self, dataset):
# --> 335     java_model = self._fit_java(dataset)
#     336     model = self._create_model(java_model)
#     337     return self._copyValues(model)
#
# File /usr/lib/spark/python/pyspark/ml/wrapper.py:332, in JavaEstimator._fit_java(self, dataset)
#     318 """
#     319 Fits a Java model to the input dataset.
#     320
#    (...)
#     329     fitted Java model
#     330 """
#     331 self._transfer_params_to_java()
# --> 332 return self._java_obj.fit(dataset._jdf)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1303, in JavaMember.__call__(self, *args)
#    1296 args_command, temp_args = self._build_args(*args)
#    1298 command = proto.CALL_COMMAND_NAME +\
#    1299     self.command_header +\
#    1300     args_command +\
#    1301     proto.END_COMMAND_PART
# -> 1303 answer = self.gateway_client.send_command(command)
#    1304 return_value = get_return_value(
#    1305     answer, self.gateway_client, self.target_id, self.name)
#    1307 for temp_arg in temp_args:
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1033, in GatewayClient.send_command(self, command, retry, binary)
#    1031 connection = self._get_connection()
#    1032 try:
# -> 1033     response = connection.send_command(command)
#    1034     if binary:
#    1035         return response, self._create_connection_guard(connection)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1200, in GatewayConnection.send_command(self, command)
#    1196     raise Py4JNetworkError(
#    1197         "Error while sending", e, proto.ERROR_ON_SEND)
#    1199 try:
# -> 1200     answer = smart_decode(self.stream.readline()[:-1])
#    1201     logger.debug("Answer received: {0}".format(answer))
#    1202     if answer.startswith(proto.RETURN_MESSAGE):
#
# File /opt/conda/miniconda3/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4.2 TF-IDF

# %%
feature_tfidf = [hashing_tf, idf]
# define pipeline that does feature engineering
pipeline_feat = Pipeline(stages=[tokenizer, remover]+feature_tfidf)
    
# Fit the pipeline to training text
pipeline_tfidf = pipeline_feat.fit(train_data)

# %% [markdown]
# ### 4.2.1 Naive Bayes

# %%
model_nb = train(train_data, pipeline_tfidf, NaiveBayes(smoothing=2.0, modelType="multinomial"))
res = evaluate(test_data, pipeline_tfidf, model_nb)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# accuracy 0.725648173613021
# precision 0.7248361131856278
# recall 0.7277377644662354
# auc 0.5162181392990665

# %%
# cross validation
res = crossvalidation(train_data, test_data, nb_model, nb_grid, cv_evaluator, pipeline_tfidf)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# [0.7235561146479446, 0.7235561235626111, 0.7235614779567637, 0.7235757669304754, 0.7235704361727662, 0.7235998786096178]
# [{Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 0.0}, {Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 0.5}, {Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 1.0}, {Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 2.0}, {Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 3.0}, {Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 5.0}]
# {Param(parent='NaiveBayes_b04f27b8850e', name='smoothing', doc='The smoothing parameter, should be >= 0, default is 1.0'): 5.0}
# accuracy 0.7256856764257319
# precision 0.7249275819423809
# recall 0.7276544516139782
# auc 0.5162080762348076

# %% [markdown]
# ### 4.2.2 SVM

# %%
model_svm = train(train_data, pipeline_tfidf, svm)
res = evaluate(test_data, pipeline_tfidf, model_svm)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# accuracy 0.738276204048637
# precision 0.7321666943922617
# recall 0.7516985407753927
# auc 0.8107737877241844

# %%
# cross validation
res = crossvalidation(train_data, test_data, svm_model, svm_grid, cv_evaluator, pipeline_tfidf)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# [0.7350326692746728, 0.7348291076077214, 0.7346505204953356, 0.7363621699088638, 0.7360717010200827, 0.735457429592322, 0.7361673100101628, 0.7355629429348551, 0.7352718474494369]
# [{Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.1}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.2}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.1}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.2}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.1}, {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 20, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.2}]
# {Param(parent='LinearSVC_27e283c066f1', name='maxIter', doc='max number of iterations (>= 0).'): 10, Param(parent='LinearSVC_27e283c066f1', name='regParam', doc='regularization parameter (>= 0).'): 0.0}
# accuracy 0.738276204048637
# precision 0.7321666943922617
# recall 0.7516985407753927
# auc 0.8107732264680664

# %% [markdown]
# ### 4.2.3 Logistic Regression

# %%
model_lr = train(train_data, pipeline_tfidf, lr)
res = evaluate(test_data, pipeline_tfidf, model_lr)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# accuracy 0.7381699460792893
# precision 0.7302517693094258
# recall 0.7556309074019304
# auc 0.8124305440290557

# %%
# cross validation
res = crossvalidation(train_data, test_data, lr_model, lr_grid, cv_evaluator, pipeline_tfidf)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# [0.7368459249301867, 0.7368459249301867, 0.7368459249301867, 0.7368459249301867, 0.7368459249301867, 0.7368459249301867, 0.7368459249301867, 0.7368459249301867, 0.7368459249301867]
# [{Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 20}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 50}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 20}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 50}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 20}, {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 50}]
# {Param(parent='LogisticRegression_fae272cd68a7', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.0, Param(parent='LogisticRegression_b81f07f04667', name='maxIter', doc='max number of iterations (>= 0).'): 10}
# accuracy 0.7381407772249585
# precision 0.7300772449308014
# recall 0.7559308336700561
# auc 0.8124262914202638

# %% [markdown]
# ### 4.2.4 Decision Tree

# %%
model_dt = train(train_data, pipeline_tfidf, dt)
res = evaluate(test_data, pipeline_tfidf, model_dt)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# accuracy 0.5481621528204338
# precision 0.7498324577901723
# recall 0.1444522185295318
# auc 0.5242643112330101
# [Stage 23:>                                                         (0 + 2) / 2]

# %% [markdown]
# ### 4.2.5 Random Forest

# %%
model_rf = train(train_data, pipeline_tfidf, rf)
res = evaluate(test_data, pipeline_tfidf, model_rf)
for metric, score in zip(metrics, res):
    print(metric, score)
# Out:
# accuracy 0.6658726572732024
# precision 0.6330232325088103
# recall 0.7892292827573569
# auc 0.7340144358999441
# [Stage 23:>                                                         (0 + 2) / 2]
